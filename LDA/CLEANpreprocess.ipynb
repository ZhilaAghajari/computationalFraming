# %% [markdown]
# Simplest preprocessing code pipeline:

# %%
#CONNECT TO SQL
import pymysql
pymysql.install_as_MySQLdb()
import MySQLdb

sql_db = MySQLdb.connect(host='127.0.0.1',user='covidAnalysis', password = "k34p63MbDDcZ9yf4",db='covid19framing')
cursor = sql_db.cursor()

# %%
#FILL STOPWORD LIST
#Real all the stop words and add them to the list of extra stop words..
extra_stop_words = open('Stopword_list.txt', 'r')
#Adding some stop words...
extra_stop_words_list = extra_stop_words.readlines()
extra_stopwords = set()
for item in extra_stop_words_list:
    extra_stopwords.add(item.strip())
extra_stopwords.add('amp');extra_stopwords.add('&amp');extra_stopwords.add('&amp;')

# %%
#Pre-processing 
#Method uses Amin's code 
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim import similarities

import csv, sys
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet


import pandas as pd
import numpy as np

import copy


try:
	csv.field_size_limit(sys.maxsize)
except:
	print('Error in setting maxSize for CSV output')
    
def preprocess_data(doc_list, id_list, extra_stopwords = {},len_th=4,lemmatized=False):
	'''
	Returns: a list of process dataset and origianl documents of those documents

	This function removes stop-wrods, lemmatized the documens, if stated, and eliminates the documnets 
	with lenhgth of 4 or less. 
	***These processes may result in lower number of documents than the original number. To make sure 
	you receive both the original docs and the processed doc in similar order we return both.

	parameter doc_list: a list of string (documents)
	parameter extra_stopwords: NLTK.stop_words are used, if you wish to add to that list, you can use yours.
	parameter len_th: documents with len_th and less will be removed.
	parameter lemmatized: If true, the terms will be lemmatized. **be aware that lemmatization of the documents
	will result in different topics and may need different evaluation, including NPMI, stability, or human assessment**

	'''

	# replace single smart quote with single straight quote, so as to catch stopword contractions
	doc_list = [re.sub("[\u2018\u2019]", "'", doc) for doc in doc_list] #replace qoute with regualar qoutations
	doc_list = [re.sub('\d+', '', doc) for doc in doc_list]
	doc_list = [re.sub('(\/.*?\.[\w:]+)', '', doc) for doc in doc_list]
	#doc_list = [re.sub('pdf|icon|jpg', '', doc) for doc in doc_list]
	#doc_list = [re.sub('(http(s)?:\/\/.)?(www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b([-a-zA-Z0-9@:%_\+.~#?&//=]*)', '', doc) for doc in doc_list]
	doc_list = [re.sub(r"http\S+", '', doc) for doc in doc_list]

	# initialize regex tokenizer
	tokenizer = RegexpTokenizer(r'\w+')
	# create English stop words list
	en_stop = set(stopwords.words('english'))
	# add any extra stopwords
	if (len(extra_stopwords) > 0):
		en_stop = en_stop.union(extra_stopwords)

	#defining a lemmatizer
	lemmatizer = WordNetLemmatizer()

	# list for tokenized documents in loop
	texts = []
	original_docs = []
	# loop through document list
	c = 0 #counter on the document number
	for i in doc_list:
		# clean and tokenize document string
		raw = i.lower()
		tokens = tokenizer.tokenize(raw)
		stopped_tokens = []
		# remove stop words from tokens
		#stopped_tokens = [i for i in tokens if not i in en_stop and len(i)>1]
		if lemmatized:
		  for t in tokens:
		    if t not in en_stop and len(t)>1:
		      pos=nltk_tag_to_wordnet_tag(nltk.pos_tag([t])[0][1])
		      if pos:
		        stopped_tokens.append(lemmatizer.lemmatize(t,pos=pos))
		      else:
		        stopped_tokens.append(lemmatizer.lemmatize(t))
		  #     print(t,pos,nltk.pos_tag([t])[0][1])
		  # print(stopped_tokens)
		  #stopped_tokens = [lemmatizer.lemmatize(i,pos=nltk_tag_to_wordnet_tag(nltk.pos_tag([i])[0][1])) for i in tokens if not i in en_stop and len(i)>1]
		else:
		  stopped_tokens = [i for i in tokens if not i in en_stop and len(i)>1]


		# add tokens to list
		if len(stopped_tokens) >= len_th:
		  texts.append([stopped_tokens, i, id_list[c]]) # [pre-processed text (tokenized), original, id]
		  #original_docs.append([i,c])

		c += 1

	return texts
# Out:
# [nltk_data] Downloading package stopwords to /home/lem325/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/lem325/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/lem325/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/lem325/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#PREPROCESS AND UPDATE IN DB

cursorUpdate = sql_db.cursor()
offset = 0#counter for offset
results = [0] #starting with a non-empty results to make sure we get into loop in the first place
# Go through and fix each piece/evaluate 
i = 0
while results:
    cursor.execute("select * from twitter where text_preproc is NULL limit 1000 offset {0};".format(offset))
    offset += 1000
    results = cursor.fetchall()
    if not results:  # Check if there are no more results
        break
    result_dic = {i[0]:i for i in results}
#     print(type([i[0] for i in results]), type([i[1].decode() for i in results]))
    
#     print(results[0])1
    #send to pre_process (...)
    out = preprocess_data([i[3] for i in results], [i[0] for i in results], extra_stopwords,len_th=4,lemmatized=False)
    #out ==> 1. pre_prcesed doc, original, id
    #print(type(out))
    #print(out)
    #putting it back to DB
    for o in out:
        cursor.execute("update twitter SET text_preproc = '{0}' where id = {1}".format(' '.join(o[0]),o[2]))
        print(o[0], o[2])
    i+=1
    if i == 10:
        break
    #cursor.fetchall()
    #offset += 1000
    
    
sql_db.commit()
# Out:
# ['whcovidresponse', 'aftunion', 'neatoday', 'speaking', 'schools', 'school', 'covid', 'policies', 'pediatric', 'response', 'huge', 'failure', 'week', 'ending', 'th', 'almost', 'child', 'covid', 'cases', 'reported', 'increase', 'previous', 'week', 'far', 'higher', 'year', 'ago', 'cases', 'undercounted', 'kids', 'told', 'go', 'school', 'unmasked'] 127048
# ['special', 'issue', 'structural', 'chemistry', 'applications', 'chem', 'bioinformatic', 'chemometric', 'machine', 'learning', 'approaches', 'covid', 'related', 'research', 'volume', 'issue', 'october', 'compchem', 'cheminformatics', 'chemometrics', 'machinelearning', 'covid'] 127049
# ['jeromeadamsmd', 'lifeatpurdue', 'please', 'explain', 'numbers', 'covid', 'feel', 'cooking', 'books'] 127050
# ['shared', 'pathophysiology', 'lung', 'kidney', 'injury', 'covid', 'natrevneph', 'covid_', 'covid', 'medtwitter', 'scienceresearch'] 127051
# ['chinese', 'mainland', 'reported', 'new', 'confirmed', 'covid', 'cases', 'thursday', 'including', 'domestically', 'transmitted', 'imported', 'data', 'national', 'health', 'commission', 'showed', 'friday'] 127052
# ['diamondandsilk', 'realcandaceo', 'ladies', 'really', 'wrong', 'still', 'supporting', 'trump', 'insurrection', 'inciting', 'covid', 'cover', 'upping', 'classifeddocuments', 'stealing', 'self', 'must', 'aware', 'republicans', 'manufacturing', 'race', 'based', 'culture'] 127053
# ['chengdu', 'sichuan', 'china', 'covid', 'chengdu', 'blocked', 'epidemic', 'city', 'million', 'people', 'locked', 'people', 'chengdu', 'frantically', 'rushing', 'buy', 'supplies', 'knew', 'people', 'starved', 'death', 'shanghai'] 127054
# ['away', 'bad', 'effort', 'post', 'pandemic', 'country', 'australia', 'covidisnotover', 'covidisairborne', 'covid', 'grandmothers', 'grandfathers', 'fathers', 'mothers', 'daughters', 'sons', 'brothers', 'sisters', 'uncles', 'aunts', 'cousins', 'friends', 'humans', 'people'] 127055
# ['test', 'scores', 'released', 'showed', 'american', 'year', 'olds', 'reading', 'mathematics', 'achievement', 'levels', 'dropped', 'levels', 'last', 'seen', 'decades', 'ago', 'revealing', 'damage', 'covid', 'pandemic', 'wrought', 'education'] 127056
# ['trump', 'biggest', 'crime', 'covid', 'response', 'sabotage'] 127057
# ['good', 'thing', 'purchased', 'ml', 'big', 'chocolatemilk', 'morn', 'report', 'based', 'covid', 'hit', 'fan', 'oz', 'kids', 'lost', 'parents', 'coronavirus', 'wear', 'fucking', 'mask', 'covidaus'] 127058
# ['test', 'results', 'showed', 'covid', 'pandemic', 'devastating', 'effects', 'american', 'schoolchildren', 'performance', 'year', 'olds', 'math', 'reading', 'dropping', 'levels', 'decades', 'ago', 'declines', 'spanned', 'almost', 'races', 'income', 'levels'] 127059
# ['join', '𝗙𝗹𝘂𝗧𝗿𝗮𝗰𝗸𝗶𝗻𝗴', 'hkusph', 'inviting', 'hong', 'kong', 'residents', 'participate', 'online', 'respiratory', 'disease', 'surveillance', 'system', 'monitoring', 'activity', 'covid', 'influenza', 'registration', 'enquiry'] 127060
# ['number', 'covid', 'cases', 'worldwide', 'surpassed', 'million', 'according', 'latest', 'data', 'world', 'health', 'organization', 'read', 'full'] 127061
# ['sure', 'read', 'comments', 'covid', 'covidvaccine', 'vaccinemandate', 'science', 'ivermectin'] 127062
# ['daily', 'reminder', 'qldhealth', 'want', 'hear', 'covid', 'deaths', 'qldpol', 'auspol', 'publichealth'] 127063
# ['drgregkelly', 'cdc', 'cheering', 'kids', 'go', 'school', 'unmasked', 'students', 'returning', 'schools', 'amid', 'high', 'level', 'covid', 'transmission', 'rise', 'airborne', 'monkeypox', 'without', 'mask', 'requirements', 'without', 'meaningful', 'distancing', 'measures', 'cases', 'without', 'proper', 'ventilation'] 127064
# ['protecting', 'loved', 'ones', 'everyones', 'number', 'priority', 'please', 'take', 'precautions', 'appropriate', 'measures', 'regarding', 'personal', 'hygiene', 'washyourhands', 'personalhygiene', 'covid', 'precaution', 'soap', 'water', 'coronavirus', 'staysafe'] 127065
# ['time', 'voices', 'dissent', 'healthcare', 'workers', 'gagged', 'speaking', 'nsw', 'anything', 'pilltesting', 'covid', 'voices', 'hear', 'narratives', 'told', 'pre', 'approved'] 127066
# ['strict', 'covid', 'control', 'measures', 'china', 'overtaken', 'sour', 'china', 'relations', 'top', 'concern', 'companies', 'country', 'business', 'lobby', 'firms', 'reported', 'issue', 'reason', 'cancel', 'delay', 'investments', 'china'] 127067
# ['cdc', 'recommends', 'updated', 'covid', 'booster', 'everyone', 'ages', 'older', 'learn', 'visiting', 'link', 'bio', 'publichealth', 'coronavirus'] 127068
# ['covid', 'vaccination', 'breakthrough', 'infections', 'patients', 'cancer', 'dec', 'dr_aschmidt', 'et', 'al', 'drchoueiri', 'covidnccc', 'annals_oncology', 'covid', 'covidvaccine', 'ccc', 'covidncancer', 'idonc'] 127069
# ['convalescent', 'plasma', 'survival', 'hematologic', 'malignancy', 'covid', 'jun', 'mtmdphd', 'drjphenderson', 'et', 'al', 'jwsenefeld', 'drdimpyshah', 'hemoncwarner', 'covidnccc', 'jamaonc'] 127070
# ['care', 'without', 'compass', 'including', 'patients', 'cancer', 'covid', 'studies', 'apr', 'chrisfriese_rn', 'drchoueiri', 'narjustdumamd', 'pgrivasmdphd', 'brian_rini', 'drdimpyshah', 'mtmdphd', 'pergamic', 'ecquis', 'hemoncwarner', 'cancer_cell', 'covidncancer', 'ccc'] 127071
# ['convalescent', 'plasma', 'improved', 'survival', 'patients', 'lkschskwx', 'ccc', 'covidncancer', 'covid'] 127072
# ['characteristics', 'outcomes', 'sars', 'cov', 'infection', 'patients', 'invasive', 'breast', 'cancer', 'bc', 'covid', 'cancer', 'consortium', 'ccc', 'cohort', 'study', 'arkhaki', 'et', 'al', 'covidnccc', 'sabcssanantonio', 'poster', 'ps', 'sabcs', 'bcsm', 'covidncancer', 'covid'] 127073
# ['systemic', 'cancer', 'treatment', 'related', 'outcomes', 'patients', 'sars', 'cov', 'infection', 'ccc', 'registry', 'analysis', 'sep', 'tmwisedraper', 'et', 'al', 'covidnccc', 'lba', 'esmo', 'covidncancer', 'covid'] 127074
# ['covid', 'particularly', 'hard', 'parents', 'recent', 'study', 'reported', 'nearly', 'working', 'parents', 'burned', 'mean', 'parent', 'focused', 'healthcomm', 'materials', 'communicatehlth', 'thoughts', 'healthliteracy'] 127075
# ['venous', 'thrombotic', 'complications', 'cancer', 'patients', 'neqvzjiq', 'vte', 'covid', 'covidncancer', 'covidnccc'] 127076
# ['today', 'reporting', 'new', 'community', 'cases', 'covid', 'people', 'hospital', 'icu'] 127077
# ['clinical', 'impact', 'covid', 'patients', 'cancer', 'ccc', 'cohort', 'study', 'may', 'nicolekuderer', 'drchoueiri', 'et', 'al', 'brian_rini', 'hemoncwarner', 'thelancet', 'covidnccc'] 127078
# ['good', 'thing', 'petrol', 'station', 'found', 'way', 'thesisingspace', 'cheaper', 'petrol', 'big', 'chocolatemilk', 'first', 'mins', 'thesising', 'involved', 'healthdept', 'website', 'finishing', 'covid', 'phdchat'] 127079
# ['utilization', 'covid', 'treatments', 'clinical', 'outcomes', 'among', 'patients', 'cancer', 'covid', 'cancer', 'consortium', 'ccc', 'cohort', 'study', 'jul', 'drdonnarivera', 'peters_solange', 'et', 'al', 'gary_lyman', 'hemoncwarner', 'cd_aacr', 'aacrcovid', 'covidncancer'] 127080
# ['great', 'news', 'covid', 'boosters', 'updated', 'current', 'omicron', 'subvariants', 'approved', 'getting', 'vaccine', 'protection', 'date', 'especially', 'important', 'older', 'people', 'az', 'covid', 'deaths', 'past', 'months', 'people', 'older', 'rollupyoursleeve'] 127081
# ['patients', 'recently', 'treated', 'lymphoid', 'malignancies', 'show', 'increased', 'risk', 'severe', 'covid', 'ccc', 'registry', 'analysis', 'mar', 'rubinstein_md', 'et', 'al', 'mtmdphd', 'covidnccc', 'bcd_aacr', 'covidncancer', 'covid', 'bmtsm', 'leusm', 'lymsm', 'mmsm', 'mpnsm'] 127082
# ['need', 'help', 'booking', 'covid', 'vaccine', 'text', 'hey', 'eva', 'receive', 'call', 'back', 'trained', 'call', 'agent', 'arrange', 'time', 'appointment', 'eva', 'operates', 'pm', 'aest', 'days', 'week'] 127083
# ['benjaminmmeier', 'died', 'meaning', 'died', 'covid', 'oregon', 'states', 'may', 'please', 'explain', 'public', 'going', 'oregon', 'northcarolina', 'ohaoregon', 'drpanmd'] 127084
# ['great', 'job', 'cnn', 'open', 'article', 'covid', 'boosters', 'first', 'thing', 'see', 'vaccine', 'denier'] 127085
# ['going', 'rates', 'covid', 'ba', 'cdnpoli', 'onpoli', 'bcpoli', 'leafs', 'habs', 'senssickos', 'quebec', 'nbpoli', 'nspoli', 'peipoli', 'nlpoli', 'longer', 'minutes', 'exposure', 'elevator', 'ride', 'brief', 'chat'] 127086
# ['coronavirus', 'update', 'total', 'cases', 'current', 'cases', 'deaths', 'recovered', 'updated', 'hours', 'coronavirus', 'covid', 'covidー', 'source'] 127087
# ['china', 'mega', 'city', 'chengdu', 'population', 'mln', 'locks', 'bphmpna'] 127088
# ['covid', 'vaccine', 'effectiveness', 'age', 'groups', 'worse', 'omicron', 'variants', 'earlier', 'strains', 'particularly', 'currently', 'dominant', 'subvariants', 'according', 'recent', 'cdcgov', 'data'] 127089
# ['zerohedge', 'ridiculous', 'lie', 'bankofcanada', 'jeremy', 'kronick', 'must', 'consuming', 'chronic', 'violation', 'accounting', 'principle', 'debit', 'credits', 'boc', 'print', 'read', 'issue', 'kind', 'monetary', 'instrument', 'case', 'covid', 'pierrepoilievre'] 127090
# ['kathyras', 'nbcnews', 'joebiden', 'potus', 'created', 'mess', 'keystonepipeline', 'shut', 'led', 'higher', 'oil', 'gas', 'food', 'prices', 'supplychain', 'broken', 'bordercrisis', 'interestrates', 'raised', 'inflation', 'covid', 'deaths', 'trump', 'afghanistan', 'taxes', 'ppl', 'back', 'work', 'jobs', 'growth', 'cnn', 'foxnews', 'abc'] 127091
# ['thought', 'allergies', 'today', 'decided', 'check', 'anyway', 'idea', 'got', 'covid'] 127092
# ['concern', 'hundreds', 'thousands', 'chinese', 'detained', 'shenzhen', 'covid', 'shenzhen', 'lockdown', 'confinement', 'humanrightscrisis'] 127093
# ['deaths', 'reported', 'new', 'infected', 'people', 'admitted', 'hospital', 'friday', 'discharged', 'still', 'treated', 'whatshappeninginthailand', 'thailand', 'covid', 'omicrons', 'โคว', 'ดว', 'นน'] 127094
# ['stevesisolak', 'govsisolak', 'elizabethrray', 'mbrasseaux', 'stevesisolak', 'wheelchairuser', 'richard', 'wert', 'forget', 'lazy', 'noreplysteve', 'lazy', 'watch', 'video', 'noreplystevemustgo', 'watch', 'video', 'covid', 'video', 'sisolak', 'email'] 127095
# ['joelombardonv', 'govsisolak', 'elizabethrray', 'mbrasseaux', 'stevesisolak', 'wheelchairuser', 'richard', 'wert', 'forget', 'lazy', 'noreplysteve', 'lazy', 'watch', 'video', 'noreplystevemustgo', 'watch', 'video', 'covid', 'video', 'sisolak', 'email'] 127096
# ['cdw', 'executive', 'summit', 'side', 'effects', 'hybrid', 'work', 'seattle', 'children', 'tech', 'covid', 'live', 'coronavirus', 'news', 'video', 'ripple', 'tacoma', 'daysofcode', 'twitch', 'youtube', 'btc', 'bitcoin', 'xrp', 'business', 'cdwsocial'] 127097
# ['fight', 'corona', 'vr', 'available', 'ue', 'unrealengine', 'indiedev', 'gamer', 'indiegamedev', 'indiegames', 'chvr', 'covid', 'coronavirus', 'virtualreality', 'gamedev', 'gamers', 'htcvive', 'oculus', 'steam', 'sales', 'pcgaming', 'pc', 'pcgamer', 'follow'] 127098
# ['markriddle', 'pro', 'tip', 'remember', 'post', 'infectious', 'lactose', 'intolerance', 'pi', 'ibs', 'causes', 'gi', 'symptoms', 'returning', 'travel', 'pi', 'ibs', 'happening', 'covid', 'ask', 'patients', 'ibs', 'prior', 'gi', 'infections'] 127099
# ['nice', 'reinvent', 'wheel', 'time', 'comes', 'advice', 'atagi', 'people', 'eligible', 'booster', 'months', 'last', 'dose', 'create', 'certainty', 'covid', 'vaccines'] 127100
# ['yelp', 'reviews', 'focus', 'covid', 'protocols', 'mask', 'adherence', 'quality', 'curbside', 'pickup', 'air', 'quality', 'consider', 'easy', 'way', 'help', 'reality', 'aware', 'people', 'especially', 'immunocompromised', 'avoid', 'dangerous', 'spaces', 'someone', 'comment', 'efforts'] 127101
# ['guatemala', 'health', 'ministry', 'registers', 'new', 'cases', 'covid', 'total', 'patients', 'died', 'patients', 'recovered', 'tests', 'carried', 'positive', 'rate', 'estimated', 'cases', 'coronavirusgt', 'remain', 'active'] 127102
# ['wcplonline', 'librarians', 'recognized', 'efforts', 'keep', 'kids', 'reading', 'engaged', 'covid', 'shutdown', 'specifically', 'storytimeanytime', 'online', 'storytime', 'program', 'special', 'guests', 'vp', 'kamala', 'harris', 'event', 'today', 'cityofdurhamnc'] 127103
# ['compelling', 'public', 'health', 'medical', 'rational', 'anymore', 'covid', 'vaccines', 'certainly', 'boosters', 'dr', 'martha', 'fulford', 'mcmaster', 'covid', 'vaccineinjuries'] 127104
# ['fresh', 'beats', 'brucedayne', 'via', 'new', 'instrumental', 'music', 'released', 'daily', 'covid', 'tags', 'rap', 'rapping', 'trapproducer', 'single', 'mood', 'vibes', 'musicnews', 'playlist', 'beat', 'music', 'raps', 'single', 'song', 'trap', 'drill', 'hiphop', 'indie', 'musica', 'art', 'artist'] 127105
# ['thailand', 'recorded', 'new', 'hospitalised', 'covid', 'infections', 'deaths', 'today', 'thaipbsworld', 'thailandnews', 'thailandupdate'] 127106
# ['world', 'vaccines', 'usa', 'uk', 'italy', 'germany', 'france', 'spain', 'turkey', 'china', 'null', 'japan', 'india', 'brazil', 'africa', 'covid', 'covid'] 127107
# ['worst', 'counties', 'terms', 'weekly', 'new', 'covid', 'cases', 'per', 'capita', 'talladega', 'county', 'alabama', 'new', 'cases', 'per', 'capita', 'last', 'week', 'per', 'note', 'county', 'fatality', 'data', 'missing', 'fl'] 127108
# ['covid', 'day', 'kid', 'taking', 'daily', 'covid', 'nap', 'covidisnotover', 'covid'] 127109
# ['sep', 'hsn', 'covid', 'update', 'changes', 'update', 'aug', 'total', 'covid', 'patients', 'icu', 'units', 'past', 'ves', 'admitted', 'icu', 'units', 'outbreaks', 'sudbury', 'covid', 'ontario'] 127110
# ['may', 'study', 'americans', 'willingness', 'actually', 'install', 'use', 'covid', 'app', 'hinges', 'benefit', 'accuracy', 'privacy', 'survey', 'americans', 'download', 'covid', 'app', 'concerns', 'privacy', 'dcinetwork', 'covid', 'privacy'] 127111
# ['new', 'rules', 'covid', 'protocol', 'halton', 'district', 'school', 'board', 'schools', 'georgetown', 'acton', 'school', 'year', 'parents', 'students', 'need'] 127112
# ['ccp', 'regime', 'placed', 'million', 'southern', 'megacity', 'chengdu', 'lockdown', 'largest', 'move', 'contain', 'covid', 'flareups', 'since', 'shanghai', 'shutdown'] 127113
# ['new', 'rules', 'covid', 'protocol', 'halton', 'district', 'school', 'board', 'schools', 'oakville', 'school', 'year', 'parents', 'students', 'need'] 127114
# ['new', 'rules', 'covid', 'protocol', 'haltondsb', 'schools', 'burlington', 'school', 'year', 'parents', 'students', 'need'] 127115
# ['new', 'rules', 'covid', 'protocol', 'halton', 'district', 'school', 'board', 'schools', 'milton', 'school', 'year', 'parents', 'students', 'need'] 127116
# ['new', 'rules', 'covid', 'protocol', 'halton', 'district', 'school', 'board', 'schools', 'oakville', 'burlington', 'milton', 'halton', 'hills', 'school', 'year', 'parents', 'students', 'need'] 127117
# ['heard', 'chengdu', 'locked', 'far', 'shenzhen', 'avoided', 'similar', 'city', 'wide', 'lockdown', 'little', 'comfort', 'part', 'city', 'get', 'locked', 'though', 'afaik', 'cases', 'still', 'rising', 'china', 'covid'] 127118
# ['domestic', 'covid', 'status', 'update', 'september', 'total', 'acquired', 'locally', 'coronavirus', 'covid', 'covidkorea', 'covid'] 127119
# ['volunteers', 'long', 'history', 'imparting', 'knowledge', 'experience', 'local', 'partners', 'academic', 'civil', 'society', 'sector', 'great', 'meet', 'first', 'batch', 'new', 'volunteers', 'week', 'embassy', 'since', 'end', 'covid', 'border', 'restrictions'] 127120
# ['since', 'start', 'pandemic', 'americans', 'died', 'covid', 'deaths', 'worldwide', 'comair', 'flight', 'killed', 'people'] 127121
# ['min', 'sec', 'min', 'sec', 'covid'] 127122
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127123
# ['economic', 'devastation', 'covid', 'compounded', 'foundation', 'laid', 'self', 'inflicted', 'trauma', 'demonetisation', 'immediate', 'context', 'reasoning', 'behind', 'demonetisation', 'essentially', 'political', 'replug'] 127124
# ['covid', 'rules', 'well', 'seeing', 'really', 'mixed', 'bag', 'takes', 'covid', 'rules', 'measures', 'changed', 'different', 'places', 'going', 'legitimately', 'confusing', 'usual', 'going', 'potentially', 'everyone', 'mad', 'sigh', 'agreeing', 'aspects', 'viewpoints'] 127125
# ['davidwa', 'daves', 'lowbird', 'toadmeister', 'believe', 'smart', 'phones', 'spectrum', 'apps', 'derived', 'science', 'lucky', 'chance', 'miracle', 'mention', 'covid', 'vaccines'] 127126
# ['today', 'thegreenmurphy', 'finishes', 'union', 'years', 'chief', 'executive', 'several', 'years', 'director', 'meaamedia', 'thank', 'paul', 'brilliant', 'leadership', 'time', 'especially', 'covid', 'pandemic', 'strongertogether'] 127127
# ['country', 'obsessed', 'winning', 'whatever', 'false', 'concept', 'stopped', 'calculating', 'basically', 'running', 'madness', 'delusion', 'enjoy', 'bidenwin', 'child', 'massacre', 'going', 'covid', 'seems', 'care', 'tradition', 'covid'] 127128
# ['beyond', 'cked', 'ontario', 'covidisairborne', 'aerosol', 'onpoli', 'homicidal', 'gov', 'ableism', 'healthsupremacy', 'covid'] 127129
# ['co', 'host', 'onairwithmike', 'tested', 'positive', 'covid', 'support', 'prayers', 'appreciated', 'advance'] 127130
# ['hi', 'ptv_official', 'bother', 'enforcing', 'mask', 'law', 'might', 'suggest', 'metrotrains', 'least', 'non', 'mask', 'carriage', 'idiots', 'together', 'coughin', 'carriage', 'covidisnotover', 'covid'] 127131
# ['qldhealth', 'private', 'public', 'difference', 'stupid', 'scientific', 'basis', 'yvettedath', 'qldlabor', 'lnpqld', 'newsqueensland', 'covid'] 127132
# ['johnrich', 'bluestar_usa', 'guy', 'standing', 'lying', 'people', 'working', 'ever', 'since', 'covid', 'half', 'employees', 'companies', 'work', 'come', 'back', 'items', 'get', 'week', 'taking', 'weeks', 'since', 'truck', 'drivers'] 127133
# ['joebiden', 'save', 'survivors', 'covid', 'suffering', 'longcovid', 'therapeutics', 'doctors', 'guidance', 'tools', 'covid', 'polls', 'self', 'preservation', 'relying', 'personal', 'risk', 'notrecovered', 'drsanjaygupta'] 127134
# ['chron', 'tedcruz', 'fine', 'rich', 'republican', 'gets', 'loan', 'forgiven', 'ave', 'americans', 'republicans', 'wrote', 'dang', 'law', 'loans', 'senategop', 'housegop', 'received', 'forgiven', 'covid', 'gop', 'going', 'petty'] 127135
# ['fraudulent', 'covid', 'deaths', 'grieving', 'parents', 'bribed', 'big', 'money', 'change', 'child', 'death', 'certificate', 'federal', 'govt', 'pushed', 'program', 'offered', 'pay', 'funeral', 'costs', 'anyone', 'family', 'member', 'die', 'covid', 'usa'] 127136
# ['bumping', 'people', 'isolate', 'use', 'rapid', 'tests', 'properly', 'understand', 'kieran', 'moore', 'isolation', 'guidance', 'wrong', 'harmful', 'onhealth', 'covid', 'onpoli'] 127137
# ['biden', 'covid', 'longer', 'controls', 'lives', 'really', 'joe', 'people', 'lost', 'livelihood', 'careers', 'refusing', 'covid'] 127138
# ['number', 'covid', 'cases', 'worldwide', 'surpassed', 'million', 'according', 'latest', 'data', 'world', 'health', 'organization'] 127139
# ['world', 'people', 'wake', 'realize', 'lied', 'covid', 'vaccines', 'tyrannical', 'lockdowns', 'lithmus', 'tests', 'power', 'money', 'printing', 'inflation', 'fault', 'etc', 'elites', 'control', 'biden', 'usa', 'trump', 'ukraine', 'russia', 'wef'] 127140
# ['biden', 'embarrassment', 'single', 'handily', 'lost', 'afghanistan', 'ukraine', 'ruined', 'stable', 'economy', 'low', 'gas', 'prices', 'low', 'inflation', 'low', 'interest', 'rates', 'oh', 'americans', 'died', 'covid', 'watch', 'trump', 'even', 'though', 'trump', 'gave', 'vaccines', 'trump'] 127141
# ['nvgop', 'america', 'children', 'left', 'behind', 'thousands', 'americans', 'left', 'dead', 'donald', 'trump', 'turned', 'america', 'world', 'coronavirus', 'epicenter', 'even', 'though', 'covid', 'originated', 'china', 'inept', 'negligent', 'totally', 'republican'] 127142
# ['good', 'see', 'victoria', 'covid', 'hospitalisations', 'fall', 'yesterday', 'report', 'case', 'numbers', 'continue', 'fall', 'sadly', 'daily', 'death', 'toll', 'terrible', 'virus', 'still', 'double', 'figures', 'lives', 'lost', 'since', 'yesterday', 'rip'] 127143
# ['act', 'covid', 'dashboard', 'covidact', 'canberra', 'covid', 'coronavirus', 'australia'] 127144
# ['ironic', 'government', 'mailed', 'thousands', 'newly', 'printed', 'flyers', 'covid', 'promoting', 'idea', 'pandemic', 'point', 'people', 'care', 'enough', 'even', 'glance', 'bcpoli', 'bc', 'covid', 'pandemic', 'bchealth', 'covid', 'bced', 'vancouver'] 127145
# ['almost', 'residents', 'long', 'term', 'care', 'facility', 'st', 'paul', 'tested', 'positive', 'covid', 'including', 'year', 'old', 'matriarch', 'cbc'] 127146
# ['sudden', 'unexpected', 'death', 'preventable', 'death', 'protectthekids', 'stoptheshots', 'clotshot', 'endthemandates', 'covid'] 127147
# ['seems', 'accurate', 'description', 'living', 'australia', 'feels', 'cruising', 'titanic', 'covid', 'pandemic', 'virus', 'get', 'climateemergency', 'auspol'] 127148
# ['govsisolak', 'joelombardonv', 'hungry', 'lot', 'years', 'noreplysteve', 'ignored', 'wheelchairuser', 'richard', 'wert', 'dumb', 'lazy', 'watch', 'video', 'noreplystevemustgo', 'watch', 'video', 'covid', 'video', 'sisolak', 'email'] 127149
# ['albomp', 'sunriseon', 'tackle', 'discrimination', 'boost', 'workforce', 'participation', 'alleviate', 'work', 'shortages', 'reinstating', 'covid', 'vaccine', 'free', 'workers', 'jobs', 'compensation', 'novaccinemandates', 'medicalapartheid'] 127150
# ['mjrowland', 'crock', 'sh', 'people', 'governments', 'relaxed', 'public', 'health', 'measures', 'right', 'time', 'needed', 'avoid', 'bad', 'press', 'anti', 'maskers', 'businesses', 'public', 'messaging', 'problem', 'covidisnotover', 'covid', 'letitrip'] 127151
# ['turning', 'lights', 'grocery', 'store', 'mid', 'day', 'already', 'going', 'long', 'cold', 'winter', 'ahead', 'europe', 'fucked', 'joing', 'ukraine', 'mess', 'back', 'stop', 'biden', 'usa', 'trump', 'ukrainerussiawar', 'russia', 'inflation', 'recession', 'food', 'wef', 'covid'] 127152
# ['cnn', 'joebiden', 'potus', 'created', 'mess', 'keystonepipeline', 'shut', 'led', 'higher', 'oil', 'gas', 'food', 'prices', 'supplychain', 'broken', 'bordercrisis', 'interestrates', 'raised', 'inflation', 'covid', 'deaths', 'trump', 'afghanistan', 'taxes', 'ppl', 'back', 'work', 'jobs', 'growth', 'cnn', 'foxnews', 'abc'] 127153
# ['washington', 'state', 'covid', 'numbers', 'wednesday', 'august', 'new', 'positive', 'case', 'new', 'death', 'coronavirus', 'covid'] 127154
# ['update', 'officials', 'cdc', 'endorsed', 'updated', 'covid', 'boosters', 'opening', 'way', 'fall', 'vaccination', 'campaign', 'blunt', 'winter', 'surge', 'enough', 'americans', 'roll', 'sleeves'] 127155
# ['nbaontnt', 'shamscharania', 'wojespn', 'chrisbhaynes', 'milesguo', 'gettr', 'talking', 'covid', 'war', 'china', 'ccp'] 127156
# ['prohibiting', 'mandatory', 'arbitration', 'ninth', 'circuit', 'agrees', 'arbitrationnews', 'arbitrate', 'arbitration', 'dispute', 'resolution', 'securities', 'investments', 'employment', 'settlement', 'payment', 'contract', 'labor', 'covid', 'ip', 'technews', 'please', 'retweet'] 127157
# ['china', 'ably', 'assisted', 'manchurian', 'candidate', 'president', 'congressmen', 'weakened', 'military', 'soldiers', 'tell', 'covid', 'accident', 'coming', 'bats', 'covidaus'] 127158
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127159
# ['doherty', 'institute', 'researchers', 'secured', 'combined', 'million', 'ausgov', 'mrff', 'grants', 'latest', 'competitive', 'round', 'covid', 'treatment', 'access', 'public', 'health', 'activity', 'katherinekedz', 'profsharonlewin', 'kanta_subbarao', 'syctong', 'thermh', 'unimelbmdhs'] 127160
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127161
# ['naep', 'scores', 'released', 'thursday', 'standard', 'calamity', 'unprecedented', 'decline', 'reading', 'math', 'scores', 'first', 'national', 'measure', 'damage', 'done', 'school', 'closures', 'america', 'children', 'covid'] 127162
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127163
# ['let', 'news', 'story', 'tag', 'favourite', 'reporter', 'tvutvmsgd'] 127164
# ['run', 'numbers', 'stage', 'losing', 'covid'] 127165
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127166
# ['cdc', 'approved', 'new', 'covid', 'omicron', 'vaccine', 'today', 'caught', 'little', 'rock', 'pharmacist', 'doctor', 'learn', 'new', 'shot', 'covid', 'omicron', 'vaccine'] 127167
# ['monashuni', 'projects', 'share', 'medical', 'research', 'future', 'fund', 'support', 'research', 'covid', 'help', 'develop', 'new', 'enhanced', 'treatments'] 127168
# ['worldwide', 'covid', 'statistics', 'confirmed', 'cases', 'recovered', 'deaths', 'kenya', 'covid', 'statistics', 'confirmed', 'cases', 'recovered', 'deaths', 'total', 'tests', 'komeshacorona', 'covid_ke', 'covid'] 127169
# ['let', 'guess', 'moe', 'chiropractor', 'couple', 'lawyers', 'onpoli', 'onhealthcare', 'covid'] 127170
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127171
# ['today', 'endorsed', 'acip', 'recommendation', 'people', 'ages', 'older', 'receive', 'updated', 'bivalent', 'covid', 'booster', 'eligible', 'bad', 'time', 'get', 'covid', 'booster', 'strongly', 'encourage', 'receive'] 127172
# ['removeddata', 'people', 'died', 'covid', 'infections', 'boostershots'] 127173
# ['cdc', 'recommends', 'first', 'updated', 'covid', 'booster', 'acip', 'covid', 'covidvaccines', 'fda', 'mrna', 'pfe', 'bntx', 'omicronba', 'ba', 'ba'] 127174
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127175
# ['facial', 'nerve', 'paralysis', 'unique', 'sequelae', 'covid', 'read', 'open', 'access', 'systematic', 'review'] 127176
# ['hawaii', 'average', 'covid', 'case', 'counts', 'still', 'declining', 'updated', 'boosters', 'took', 'step', 'closer', 'availability', 'read', 'hinews', 'staradvertiser'] 127177
# ['taking', 'applications', 'texasecondev', 'established', 'time', 'reimbursement', 'grants', 'recovery', 'texasbusinesses', 'tourism', 'travel', 'hospitality', 'industries', 'impacted', 'due', 'covid', 'see', 'qualify', 'link'] 127178
# ['webinar', 'sept', 'interested', 'strategies', 'used', 'ecec', 'services', 'innovation', 'covid', 'hear', 'goodstartel', 'educators', 'project', 'codesign', 'learning', 'innovation', 'support', 'reeachunimelb', 'paeadie', 'ianpotterfdn', 'ccch_au'] 127179
# ['reactive_news', 'richardursomd', 'still', 'completely', 'worthless', 'covid', 'mrna', 'vaccines'] 127180
# ['archive', 'tobacco', 'industry', 'tried', 'skew', 'research', 'show', 'smokers', 'likely', 'develop', 'severe', 'covid', 'happened'] 127181
# ['covid', 'still', 'around', 'help', 'protect', 'friends', 'family', 'risk', 'severe', 'covid', 'encouraging', 'get', 'vaccine', 'booster', 'doses', 'let', 'help', 'keep', 'safe', 'practicing', 'covid', 'protective', 'measures', 'even', 'vaccination'] 127182
# ['get', 'recommended', 'covid', 'vaccine', 'doses', 'pregnant', 'getting', 'vaccinated', 'important', 'protect', 'baby', 'learn'] 127183
# ['new', 'utahdhhs', 'state', 'start', 'receiving', 'newly', 'authorized', 'covid', 'omicron', 'variant', 'boosters', 'soon', 'next', 'week', 'contact', 'health', 'care', 'provider', 'pharmacy', 'local', 'health', 'department', 'get', 'fox', 'utpol', 'utah'] 127184
# ['serehfas', 'bigbaddenis', 'albomp', 'mean', 'failed', 'hard', 'fail', 'covid', 'auspol', 'unfortunately', 'fail', 'days', 'post', 'pcr', 'positive', 'super', 'spreading', 'territory', 'probably', 'viral', 'load', 'peaking', 'anyway', 'see'] 127185
# ['acknowledging', 'nsw', 'people', 'reported', 'died', 'covid', 'past', 'day', 'loved', 'ones', 'grieving', 'loss', 'care', 'vulnerable', 'people', 'community', 'please', 'wear', 'mask', 'indoors', 'stay', 'home', 'infectious'] 127186
# ['left', 'killed', 'thousands', 'people', 'denying', 'effective', 'treatments', 'covid', 'trump', 'try', 'silently', 'admit', 'evil', 'scumbags'] 127187
# ['help', 'restore', 'protection', 'waned', 'since', 'previous', 'vaccination', 'designed', 'provide', 'broader', 'protection', 'cdc', 'endorsed', 'updated', 'covid', 'shots', 'fall', 'boosters', 'comes', 'next', 'wvtm', 'covid', 'boostervaccines', 'health'] 127188
# ['covid', 'pandemic', 'cdc', 'flipped', 'public', 'health', 'population', 'control', 'whilst', 'media', 'ensured', 'north', 'americans', 'get', 'enough', 'mrna', 'kool', 'aid'] 127189
# ['panel', 'advises', 'cdcgov', 'vaccine', 'guidance', 'advised', 'agency', 'sept', 'recommend', 'updated', 'covid', 'boosters', 'americans', 'aged', 'older', 'clinical', 'data', 'available', 'boosters', 'drew', 'concern', 'panel', 'members'] 127190
# ['tonga', 'country', 'little', 'people', 'closely', 'knit', 'community', 'hence', 'responding', 'outbreak', 'covid', 'important', 'ministry', 'health', 'engaged', 'religious', 'groups', 'public', 'private', 'sector', 'partners', 'tonga', 'sbc', 'rcce', 'covid'] 127191
# ['buzz', 'across', 'ontario', 'doug', 'ford', 'stephen', 'lecce', 'intentionally', 'lifting', 'covid', 'mandates', 'schools', 'knowingly', 'covid', 'omicron', 'spread', 'wildfire', 'shut', 'schools', 'blame', 'teachers', 'onted', 'sflecce', 'fordnation', 'dougford', 'etfo'] 127192
# ['idiots', 'learned', 'nothing', 'covidisairborne', 'covidisnotover', 'covid', 'abed', 'ableg'] 127193
# ['ultimate', 'act', 'bastardry', 'tell', 'country', 'covid', 'workload', 'health', 'professionals', 'hospitals', 'tells', 'completely', 'different', 'story', 'auspol', 'covid', 'covidisnotover'] 127194
# ['covid', 'update', 'total', 'patients', 'tested', 'covid', 'michigan', 'medicine', 'since', 'pandemic', 'began', 'total', 'positive', 'tests', 'current', 'inpatients', 'covid', 'positive', 'total', 'covid', 'patients', 'discharged', 'learn'] 127195
# ['covid', 'pandemic', 'drives', 'higher', 'cancer', 'dementia', 'diabetes', 'death', 'rates', 'actuariesinst', 'actuarialeye', 'covid', 'marywardy'] 127196
# ['congratulations', 'colleagues', 'ummedschool', 'happy', 'part', 'study', 'showing', 'gene', 'determined', 'blood', 'type', 'assoc', 'veqieetpx'] 127197
# ['note', 'cdc', 'advisers', 'recommended', 'anyone', 'age', 'older', 'get', 'new', 'pfizer', 'biontech', 'boosters', 'authorized', 'us_fda', 'updated', 'moderna', 'covid', 'vaccine', 'authorized', 'anyone', 'older', 'read'] 127198
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127199
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127200
# ['nswhealth', 'prof', 'baxter', 'protections', 'removed', 'govts', 'never', 'bring', 'back', 'reassurances', 'proportionate', 'reintroduce', 'measures', 'stances', 'require', 'bs', 'covid', 'covid', 'auspol', 'albomp', 'dom_perrottet', 'guardianaus', 'smh', 'australian', 'abc', 'mark_butler_mp'] 127201
# ['tested', 'positive', 'covid', 'shortness', 'breathe', 'headache', 'temp', 'biggest', 'effects', 'far', 'update', 'along', 'way'] 127202
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127203
# ['time', 'seriously', 'consider', 'away', 'wearing', 'face', 'masks', 'enclosed', 'spaces', 'thesun', 'thesundaily', 'facemasks', 'covid', 'health', 'news', 'malaysia'] 127204
# ['albomp', 'boconnormp', 'jawestacott', 'chaythorpeaeu', 'tafedirectors', 'the_aigroup', 'duncanbentley', 'annastaciamp', 'time', 'threw', 'covid', 'bus', 'covidisnotover', 'covid', 'auspol', 'actual', 'people', 'actually', 'dying'] 127205
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127206
# ['yes', 'yes', 'yes', 'covid', 'covidisnotover'] 127207
# ['amazingkreskin', 'foresee', 'pm', 'years', 'rising', 'house', 'apologize', 'actions', 'trudeau', 'government', 'covid', 'pandemic'] 127208
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127209
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127211
# ['buy', 'google', 'voice', 'accounts', 'buy', 'usa', 'phone', 'number', 'machinelearning', 'datascience', 'python', 'ai', 'daysofcode', 'iot', 'flutter', 'javascript', 'serverless', 'china', 'buygvservice', 'tech', 'ddos', 'deeplearning', 'fintech', 'covid', 'data', 'gv资源', 'gallrounder', 'buying'] 127212
# ['answers', 'questions', 'new', 'bivalent', 'covid', 'booster', 'shot'] 127213
# ['favorite', 'brand', 'beer', 'drinkiq', 'guinnesssmoothng', 'tapintoyourbeer', 'drinkresponsily', 'covid', 'covid', 'obidatti'] 127214
# ['viral', 'claims', 'swirled', 'online', 'week', 'seeking', 'link', 'perceived', 'spike', 'excess', 'deaths', 'among', 'children', 'europe', 'covid', 'vaccines', 'experts', 'number', 'things', 'causing', 'spike', 'vaccines'] 127215
# ['nswhealth', 'afr', 'sept', 'reports', 'uk', 'icl', 'prof', 'calvani', 'study', 'shows', 'still', 'infectious', 'day', 'day', 'iso', 'insufficient', 'cut', 'transmission', 'test', 'twice', 'ending', 'iso', 'covid', 'auspoi', 'covidaus', 'covid', 'mark_butler_mp', 'abc', 'smh', 'dailytelegraph', 'australian', 'guardianaus'] 127216
# ['today', 'marks', 'beginning', 'new', 'month', 'time', 'begin', 'new', 'coronavirus', 'nightly', 'update', 'thread', 'always', 'link', 'thread', 'previous', 'update', 'threads', 'last', 'night', 'update', 'link', 'thread', 'last'] 127217
# ['need', 'new', 'moderna', 'covid', 'bivalent', 'vaccine', 'alex_n_boyd', 'via', 'torontostar', 'covid', 'cdnpoli', 'vaccination'] 127218
# ['land', 'lord', 'told', 'pay', 'started', 'tuesday', 'night', 'spare', 'amount', 'appreciated', 'helpus', 'crowdfunding', 'urgent', 'donations', 'pleasert', 'paypal', 'tenants', 'donatenow', 'donate', 'covid'] 127219
# ['menlo', 'park', 'paramus', 'veterans', 'homes', 'new', 'jersey', 'pay', 'second', 'round', 'nursing', 'home', 'covid', 'death', 'claims', 'aging', 'ltcjustice', 'ageism', 'nursinghomeabuse', 'eldercare', 'longtermcare', 'covid'] 127220
# ['however', 'wrong', 'timeline', 'read', 'lot', 'well', 'nih', 'added', 'ivermectin', 'list', 'covid', 'treatment'] 127221
# ['pubmed', 'new', 'onset', 'exacerbations', 'psoriasis', 'following', 'covid', 'vaccines', 'systematic', 'review', 'conclusions', 'new', 'onset', 'psoriasis', 'psoriasis', 'flares', 'reported', 'cutaneous', 'adverse', 'events', 'following', 'covid', 'covid', 'sarscov', 'coronavirus'] 127222
# ['everyone', 'talked', 'even', 'older', 'folks', 'tired', 'getting', 'covid', 'vaccinations', 'still', 'ending', 'virus', 'shots', 'helping', 'thursdayvibes'] 127223
# ['hosting', 'business', 'retreat', 'corporate', 'event', 'give', 'attendees', 'peace', 'mind', 'comes', 'everyone', 'present', 'covid', 'free', 'discover', 'testing', 'solutions'] 127224
# ['liztabish', 'talks', 'covid', 'shut', 'thechosentv', 'season', 'iii', 'production', 'days'] 127225
# ['fb', 'memories', 'sep', 'victoria', 'fellow', 'victorians', 'forever', 'grateful', 'extraordinary', 'efforts', 'protect', 'others', 'covid'] 127226
# ['squeezy', 'public', 'transport', 'recommendation', 'mask', 'protect', 'vulnerable', 'people', 'queensland', 'govt', 'proactively', 'trying', 'encourage', 'covid', 'infection', 'feed', 'capitalist', 'profiteers', 'capitalismisadeathcult'] 127227
# ['new', 'data', 'viz', 'examines', 'donor', 'investments', 'covid', 'vaccine', 'delivery', 'providing', 'estimates', 'create', 'transparency', 'inform', 'policy', 'resource', 'allocation', 'check'] 127228
# ['walkerbragman', 'duckyjan', 'covid', 'covidisnotover', 'deaths', 'per', 'day', 'still'] 127229
# ['government', 'telling', 'population', 'best', 'way', 'deal', 'covid', 'personal', 'responsiblity', 'community', 'respect', 'hypocrisy', 'simply', 'shelving', 'findings', 'taxpayer', 'funded', 'inquiry', 'espousing', 'virtues', 'rank'] 127230
# ['health', 'canada', 'approved', 'modern', 'omicron', 'covid', 'booster', 'vaccine', 'first', 'approved', 'vaccine', 'canada', 'targeted', 'specifically', 'omicron', 'variant'] 127231
# ['ontario', 'chief', 'medical', 'officer', 'health', 'announced', 'province', 'removing', 'day', 'isolation', 'period', 'previously', 'required', 'individuals', 'tested', 'positive', 'covid'] 127232
# ['albertaviewsmag', 'drjaredwesley', 'government', 'small', 'enough', 'drown', 'bathtub', 'government', 'want', 'midst', 'existential', 'crises', 'covid', 'pandemic', 'climateemergency', 'cdnpoli', 'abpoli', 'ableg'] 127233
# ['tough', 'pacific', 'nations', 'experiencing', 'st', 'nd', 'rd', 'waves', 'covid', 'nations', 'rely', 'tourism', 'revenue', 'income', 'economies', 'took', 'hit', 'translated', 'job', 'losses', 'deep', 'sense', 'fear', 'read', 'annual', 'results', 'report'] 127234
# ['excited', 'important', 'development', 'covid', 'vaccine', 'science', 'family', 'first', 'line', 'become', 'available', 'sent', 'kstp'] 127235
# ['reading', 'math', 'scores', 'plummet', 'levels', 'unseen', 'decades', 'thanks', 'gop', 'hmzyil', 'thursdaythoughts', 'education', 'covid', 'trumpisguiltyaf'] 127236
# ['hope', 'fluctuates', 'laci', 'texas', 'shares', 'emotional', 'roller', 'coaster', 'covid', 'hope', 'heartbreak', 'lost', 'dad', 'covid', 'november', 'please', 'listen', 'share', 'wherever', 'hear', 'favorite', 'podcasts', 'covidgrief', 'covidloss', 'yellowheartmemorial'] 127237
# ['question', 'reality', 'covid', 'bull', 'oppression', 'subversion', 'tyranny', 'wef', 'control', 'truth', 'western', 'values', 'oursharedculture', 'attacked', 'within', 'wokementality', 'enemy', 'wef', 'within'] 127238
# ['kids', 'returning', 'classroom', 'pediatrician', 'dr', 'beth', 'ebel', 'uwsomwwami', 'sensible', 'time', 'children', 'receive', 'booster', 'covid', 'vaccination', 'eligible', 'backtoschool', 'covid', 'omicron'] 127239
# ['heads', 'program', 'sends', 'free', 'covid', 'test', 'kits', 'homes', 'around', 'country', 'coming', 'pause', 'order', 'tests', 'september', 'deadline', 'share', 'info', 'widely', 'allinagainstcovid'] 127240
# ['update', 'cdc', 'director', 'agrees', 'advisers', 'recommends', 'updated', 'covid', 'vaccine', 'boosters', 'target', 'newest', 'omicron', 'strains', 'covid', 'news'] 127241
# ['ohio', 'covid', 'cases', 'went', 'last', 'week', 'ones', 'reported', 'bracing', 'fall', 'surge', 'really', 'ought', 'masking', 'public', 'forget', 'wash', 'hands'] 127242
# ['cdcdirector', 'gave', 'final', 'approval', 'updated', 'covid', 'booster', 'shots', 'moderna_tx', 'pfizer', 'target', 'omicron', 'variant', 'shots', 'available', 'soon', 'next', 'week', 'locations', 'kytxcbs'] 127243
# ['noticed', 'conversation', 'ppl', 'covid', 'really', 'uncomfortable', 'discuss', 'rigorous', 'safety', 'levels', 'express', 'bar', 'whether', 'die', 'potential', 'serious', 'consequences', 'infected', 'mild'] 127244
# ['thinning', 'hair', 'hair', 'loss', 'covid', 'solution', 'covid', 'hairloss', 'hairthinning'] 127245
# ['st', 'day', 'alert', 'level', 'quarantine', 'body', 'temperature', 'spo', 'bpm', 'pulse', 'bp', 'temperaturetwicedaily', 'detect', 'fever', 'symptom', 'covid', 'coronavirus', 'circadianrhythm'] 127246
# ['put', 'context', 'covid', 'taken', 'life', 'expectancy', 'back', 'levels', 'decade', 'setback', 'already', 'still', 'worsening', 'progress', 'years', 'screening', 'programs', 'new', 'meds', 'surgeries', 'health', 'system', 'improvements', 'reduced', 'smoking', 'safer', 'cars', 'roads', 'cancelled'] 127247
# ['research', 'articles', 'breastfeeding', 'covid', 'free', 'share', 'download', 'september'] 127248
# ['poor', 'country', 'governments', 'already', 'seriously', 'overstretched', 'covid', 'food', 'energy', 'crises', 'sparked', 'war', 'ukraine', 'notes', 'ngairewoods', 'must', 'contend', 'depreciating', 'currencies', 'rising', 'borrowing', 'costs'] 127249
# ['cdc', 'director', 'approves', 'vaccine', 'advisers', 'recommendation', 'covid', 'boosters', 'pfizer', 'people', 'ages', 'years', 'older', 'moderna', 'people', 'ages', 'years', 'older', 'updated', 'boosters', 'target', 'omicron', 'ba', 'ba', 'addition', 'original', 'strain', 'sars', 'cov', 'virus'] 127250
# ['cpho_canada', 'tested', 'safe', 'covaxin', 'approvecovaxin', 'ichoosecovaxin', 'traditional', 'whole', 'virion', 'inactivated', 'covid', 'vaccine', 'covaxin', 'ocgn'] 127251
# ['scienceupfirst', 'cihr_irsc', 'cpho_canada', 'casc_accs', 'stankutcher', 'caulfieldtim', 'ottawahealth', 'heysciencesam', 'tested', 'safe', 'covaxin', 'approvecovaxin', 'ichoosecovaxin', 'traditional', 'whole', 'virion', 'inactivated', 'covid', 'vaccine', 'covaxin', 'ocgn'] 127252
# ['fascinating', 'plot', 'showing', 'uncoupling', 'covid', 'cases', 'naat', 'pcr', 'test', 'positivity', 'related', 'home', 'testing', 'omicron', 'infections', 'reported', 'state', 'gyahgnlave'] 127253
# ['victorian', 'government', 'scrapping', 'remaining', 'workfromhome', 'recommendations', 'spring', 'breaks', 'state', 'auspol', 'covidaus', 'covid', 'cre', 'commercialrealestate', 'commercialproperty'] 127254
# ['today', 'cdcdirector', 'rochelle', 'walensky', 'endorsed', 'cdc', 'advisory', 'committee', 'immunization', 'practices', 'acip', 'recommendations', 'use', 'updated', 'covid', 'boosters', 'pfizer', 'biontech', 'people', 'ages', 'yrs', 'older', 'moderna', 'people', 'ages', 'yrs', 'older'] 127255
# ['keeping', 'mask', 'thanks', 'served', 'well', 'intend', 'getting', 'covid'] 127256
# ['health', 'experts', 'endorsed', 'launch', 'fall', 'new', 'covid', 'vaccine', 'better', 'matched', 'omicron', 'specific', 'ba', 'ba', 'variants', 'coronavirus', 'new', 'boosters', 'available', 'next', 'week'] 127257
# ['fight', 'coronavirus', 'proper', 'diet', 'good', 'nutrition'] 127258
# ['fight', 'coronavirus', 'proper', 'diet', 'good', 'nutrition'] 127259
# ['updates', 'cdcgov', 'acip', 'recommendations', 'new', 'bi', 'valent', 'covid', 'vaccines', 'time', 'get', 'updated', 'booster'] 127260
# ['dummieyblondiey', 'tedcruz', 'plz', 'never', 'forget', 'trump', 'lied', 'months', 'covid', 'hoax', 'died', 'ashishkjha', 'kavitapmd', 'leadermcconnell', 'gopleader', 'presssec'] 127261
# ['acip', 'blesses', 'bivalent', 'vaccines', 'market', 'free', 'lgxcmkaw', 'biotech', 'pharma', 'covid', 'us_fda', 'moderna_tx', 'pfizer', 'biontech_group', 'cdcgov'] 127262
# ['goodmorning', 'phone', 'slid', 'fell', 'noworries', 'happy', 'friday', 'tune', 'listen', 'allhits', 'mellow', 'karrotsscarletneil', 'theawesomewakeupshow', 'radiolife', 'manilaradio', 'fmradio', 'morningradio', 'morningradioshow', 'newnormal', 'covid'] 127263
# ['feel', 'kept', 'covid', 'free', 'whole', 'time', 'vaccine', 'simply', 'never', 'taking', 'test', 'never', 'worry', 'thing', 'covid', 'free', 'entire', 'time', 'side', 'effects', 'free', 'bullshit'] 127264
# ['feeling', 'join', 'movement', 'report', 'symptoms', 'publichealthtrack', 'covid', 'covidpandemic'] 127265
# ['govsisolak', 'access', 'food', 'luxury', 'either', 'noreplysteve', 'ignored', 'wheelchairuser', 'richard', 'wert', 'fo', 'years', 'dumb', 'lazy', 'watch', 'video', 'noreplystevemustgo', 'watch', 'video', 'covid', 'video', 'sisolak', 'email'] 127266
# ['due', 'covid', 'related', 'staffing', 'shortages', 'northburlmed', 'forced', 'adjust', 'walkinclinic', 'hours', 'weekend', 'open', 'sat', 'sep', 'may', 'close', 'early', 'days', 'thank', 'nbmc', 'ontariosdoctors', 'extra', 'shifts', 'keep', 'clinic', 'open', 'day'] 127267
# ['govsisolak', 'access', 'food', 'luxury', 'either', 'lazy', 'noreplysteve', 'ignored', 'wheelchairuser', 'richard', 'wert', 'fo', 'years', 'dumb', 'lazy', 'watch', 'video', 'noreplystevemustgo', 'watch', 'video', 'covid', 'video', 'sisolak', 'email'] 127268
# ['headline', 'read', 'growing', 'evidence', 'covid', 'vaccine', 'leaving', 'people', 'sicker', 'financial', 'times', 'covid', 'canwetalkaboutit'] 127269
# ['tragic', 'covid', 'letitrip', 'nearly', 'australian', 'children', 'lost', 'parents', 'covid', 'australia', 'news', 'guardian'] 127270
# ['thechefsgardens', 'definition', 'ethics', 'greater', 'good', 'read', 'history', 'ethics', 'chinese', 'socialist', 'government', 'practice', 'ethics', 'western', 'liberal', 'democracies', 'practice', 'ethics', 'trolley', 'problem', 'prolonged', 'covid', 'pandemic'] 127271
# ['fascinating', 'data', 'prof', 'belinda', 'gabbe', 'emergtrauma', 'impact', 'covid', 'trauma', 'survival', 'victoria', 'likely', 'relate', 'reduced', 'transport', 'trauma', 'centres', 'trauma', 'anztrauma'] 127272
# ['getting', 'victoria', 'hospital', 'covid_', 'covid', 'last', 'time', 'hospital', 'back', 'th', 'april'] 127273
# ['amapresident', 'public', 'health', 'measures', 'ama', 'calling', 'help', 'stop', 'spread', 'covid'] 127274
# ['put', 'warnings', 'mocked', 'shut', 'conspiracy', 'nutters', 'see', 'people', 'coming', 'vecglryc'] 127275
# ['september', 'jst', 'utc', 'covid', 'japan', 'new', 'cases', 'deaths', 'serious', 'condition', 'sense', 'pneumonia', 'vitality', 'nhk', 'world', 'japan', 'news', 'nhk', 'open', 'data'] 127276
# ['appointment', 'canceled', 'due', 'fda', 'bauaslwt', 'covid', 'vaccine', 'boostershots', 'moderna', 'pfizer', 'biontech'] 127277
# ['saturdaymorning', 'highriskcovidー', 'coronavirus', 'free', 'online', 'math', 'tutoring'] 127278
# ['remarkable', 'reductions', 'covid', 'mortality', 'occurred', 'among', 'older', 'americans', 'btw', 'xfucessl'] 127279
# ['cosagov', 'local', 'mental', 'health', 'advocates', 'use', 'million', 'covid', 'relief', 'money', 'step', 'larger', 'ongoing', 'effort', 'help', 'people', 'struggling', 'mental', 'health', 'challenges'] 127280
# ['victoria', 'covid', 'dashboard', 'covid', 'covidvic', 'melbourne', 'victoria', 'coviddata', 'covidaus', 'coronavirus'] 127281
# ...
# ['failed', 'everyday', 'overnight', 'life', 'changed', 'true', 'overnight', 'success', 'stories', 'real', 'day', 'part', 'mondaymotivation', 'mondayvibes', 'covid', 'crypto'] 260479
# ['got', 'negative', 'result', 'home', 'covid', 'test', 'learn', 'next', 'steps', 'symptoms', 'visit'] 260480
# ['walkingwhileretired', 'clayandbuck', 'show', 'overall', 'researchers', 'found', 'months', 'administration', 'doses', 'vaccine', 'less', 'effective', 'stopping', 'covid', 'aka', 'symptomatic', 'omicron', 'infection', 'doses', 'effective'] 260481
# ['distribution', 'day', 'covid', 'deaths', 'county', 'data', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260482
# ['several', 'large', 'randomized', 'controlled', 'trials', 'evaluated', 'use', 'antiplatelet', 'therapy', 'hospitalized', 'patients', 'covid', 'created', 'table', 'summarizes', 'results', 'trials'] 260483
# ['mask', 'covid', 'trudeaumustresign', 'done', 'people', 'ending', 'stupid', 'driving', 'around', 'alone', 'car', 'mask'] 260484
# ['electrician', 'first', 'choice', 'lagostar', 'wire', 'cable', 'keeping', 'wired', 'austriangp', 'wizkid', 'biblebuild', 'covid', 'ukraine'] 260485
# ['christinapushaw', 'next', 'set', 'covid', 'restrictions', 'issued', 'november', 'th'] 260486
# ['throughout', 'covid', 'pandemic', 'increase', 'hospital', 'admissions', 'eating', 'disorders', 'authors', 'conducted', 'study', 'describes', 'associated', 'changes', 'patient', 'demographics', 'hospitalization', 'courses', 'discharge', 'dispositions'] 260487
# ['healthy', 'eyesight', 'tip', 'let', 'eye', 'rest', 'reduce', 'eye', 'strain', 'possible', 'loveisland', 'pharmacy', 'covid', 'end'] 260488
# ['distribution', 'day', 'covid', 'deaths', 'county', 'data', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260489
# ['covid', 'update', 'sunday', 'july', 'new', 'cases', 'death', 'january', 'recoveries', 'positivity', 'rate'] 260490
# ['want', 'wrong', 'decision', 'ask', 'everyone', 'uluka', 'finance', 'decision', 'nhlanhla_lux', 'sudhirjoinedaajtak', 'heatwave', 'wimbledon', 'covid', 'เลย', 'บค', 'นก', 'นค', 'โอมนนน'] 260491
# ['birk', 'merridith', 'brandikruse', 'gavinnewsom', 'may', 'true', 'seattle', 'lowest', 'covid', 'rates', 'pros', 'mentioned', 'far', 'outweigh', 'small', 'inconvenience', 'getting', 'shot', 'plus', 'teachers', 'job', 'protect', 'kids', 'teach', 'issue', 'covid', 'covid'] 260492
# ['upperextremity', 'phlegmasiaceruleadolens', 'compartmentsyndrome', 'coronavirus', 'disease', 'sepsis', 'drhembd', 'haddockmd', 'utswnews', 'covidlimbischemia', 'limbsalvage', 'upperextremityfasciotomies', 'handsurgery', 'casereport'] 260493
# ['covid', 'contributed', 'rise', 'elearning', 'ifc_org', 'report', 'partnership', 'coursera', 'eu_commission', 'highlights', 'women', 'emerging', 'markets', 'develop', 'job', 'skills', 'access', 'post', 'secondary', 'education', 'via', 'onlinelearning'] 260494
# ['day', 'distribution', 'covid', 'deaths', 'state', 'using', 'county', 'data', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260495
# ['day', 'covid', 'deaths', 'county', 'wy', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260496
# ['old', 'memories', 'back', 'corona', 'time', 'truly', 'blessing', 'buddies', 'game', 'wrong', 'gamergirl', 'coronavirus', 'happy', 'prettyyoungteen', 'animegirl'] 260497
# ['find', 'messaging', 'merrionstreet', 'red', 'arrow', 'somewhat', 'bizarre', 'choose', 'wear', 'face', 'mask', 'require', 'approval', 'around', 'covid', 'gone', 'away'] 260498
# ['wonder', 'booster', 'uptake', 'united', 'states', 'low', 'conflicting', 'public', 'health', 'messaging', 'experts', 'mainstream', 'media', 'blame', 'covid', 'covidisnotover', 'sarscov', 'airborne', 'safeindoorair', 'ventilation', 'hepa'] 260499
# ['updated', 'page', 'alert', 'check', 'updated', 'pediatrics', 'content', 'pediatric', 'covid', 'vaccination', 'pediatric', 'covid', 'faqs', 'resources', 'multimedia', 'read', 'idsainfo', 'pidsociety', 'ameracadpeds', 'mk_connolly', 'bakstratcomms', 'hiv_tid'] 260500
# ['chrischirp', 'zoe', 'wave', 'almost', 'bad', 'late', 'march', 'early', 'april', 'covid', 'surprised', 'seems', 'taking', 'seriously'] 260501
# ['jjhorgan', 'continues', 'blame', 'ottawa', 'hour', 'wait', 'times', 'expected', 'lengths', 'stay', 'bcndp', 'management', 'major', 'emergency', 'rooms', 'vchhealthcare', 'seventh', 'covid', 'wave', 'adriandix', 'bcpoli'] 260502
# ['day', 'covid', 'deaths', 'county', 'wy', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260503
# ['vincentrk', 'ft', 'add', 'thread', 'pycoa_fr', 'histos', 'ourworldindata', 'who_europe', 'whoafro', 'covid'] 260504
# ['get', 'free', 'home', 'covid', 'testing', 'kits', 'live', 'pennsylvania', 'mailed', 'health', 'publichealth'] 260505
# ['self', 'directed', 'courses', 'taken', 'anytime', 'cover', 'topics', 'reporting', 'covid', 'datajournalism', 'investigativereporting', 'mapping', 'uncovering', 'misinformation', 'productmanagement'] 260506
# ['thoughts', 'docs', 'patient', 'chf', 'kidney', 'failure', 'pra', 'level', 'consider', 'covid', 'vaccine', 'covid', 'vaccine', 'affect', 'antibodies', 'pre', 'post', 'kidney', 'transplant', 'medtwitter', 'covid'] 260508
# ['social', 'isolation', 'thing', 'past', 'still', 'vulnerable', 'groups', 'shielding', 'indoors', 'lower', 'risk', 'catching', 'passing', 'covid', 'learn', 'mental', 'health', 'shielders', 'years', 'pandemic'] 260509
# ['excellent', 'read', 'covid', 'minimisers', 'today', 'confronted', 'ba', 'new', 'variant', 'deem', 'mild'] 260510
# ['nj', 'covid', 'since', 'june', 'st', 'covid', 'deaths', 'reported', 'ltc', 'residents', 'residents', 'vaxxed', 'longer', 'states', 'going', 'misrepresent', 'vax', 'mexklmqrd'] 260511
# ['day', 'covid', 'deaths', 'county', 'wi', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260512
# ['world', 'afford', 'ignore', 'mvankerkhove', 'reality', 'check', 'fully', 'agree', 'playing', 'fire', 'let', 'guard', 'covid', 'cases', 'spiking', 'tools', 'fight', 'virus', 'best', 'way', 'maximise', 'potential', 'ensuring', 'equitable', 'access'] 260513
# ['covid', 'vaccination', 'pregnancy', 'protects', 'infant', 'safe', 'mother'] 260514
# ['asuu', 'strike', 'nationwide', 'blackout', 'looms', 'workers', 'threaten', 'shut', 'power', 'sector', 'comment', 'share', 'gofundme', 'mondaythoughts', 'loveisland', 'sudhirjoinedaajtak', 'genshinlmpact', 'heatwave', 'wizkid', 'covid'] 260515
# ['coronavirus', 'update', 'total', 'cases', 'current', 'cases', 'deaths', 'recovered', 'updated', 'hours', 'coronavirus', 'covid', 'covidー', 'source'] 260516
# ['eye', 'eye', 'ends', 'whole', 'world', 'blind', '_mahatma', 'gandhi', 'eyecare', 'loveisland', 'covid'] 260517
# ['disgusting', 'cisss', 'lanaudiere', 'states', 'hcws', 'go', 'get', 'tested', 'covid', 'sick', 'must', 'come', 'work', 'covid', 'last', 'months', 'even', 'within', 'months', 'vaccinated', 'possible', 'get', 'reinfected', 'weeks'] 260518
# ['covid', 'symptoms', 'get', 'tested', 'testtotreat', 'location', 'program', 'get', 'tested', 'covid', 'get', 'prescription', 'treatment', 'appropriate', 'prescription', 'filled', 'appropriate'] 260519
# ['lynn', 'plugging', 'standardisation', 'efforts', 'phage', 'consortium', 'camda', 'cosi', 'showing', 'phage', 'sars', 'cov', 'contextual', 'data', 'specification', 'preprint', 'actually', 'recently', 'published', 'peer', 'reviewed', 'version'] 260520
# ['ciao', 'amici', 'happy', 'lunedì', 'luglio', 'thorloveandthunder', 'weraceasone', 'vs', 'covid', 'crohnsdisease', 'frenchgp', 'luglio', 'essereferrari', 'eusm', 'forza', 'masksall', 'vaxall', 'peaceandlove', 'xoxo'] 260521
# ['pandemic', 'changed', 'household', 'food', 'waste', 'behaviour', 'waste', 'less', 'food', 'covid', 'foodwaste', 'poll', 'interesting', 'research', 'food', 'wfh'] 260522
# ['vaccines', 'available', 'fre', 'back', 'school', 'immunizations', 'covid', 'available', 'week', 'bring', 'children', 'beat', 'last', 'minute', 'rush', 'first', 'day', 'class', 'backtoschool', 'covid', 'cityofdallas', 'rescueorg'] 260523
# ['sajidjavid', 'cancel', 'valneva', 'traditional', 'covid', 'jab', 'last', 'autumn', 'never', 'told', 'pass', 'mhra', 'certification', 'forget', 'saj'] 260524
# ['day', 'covid', 'deaths', 'county', 'wi', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260525
# ['covid', 'day', 'sitting', 'everybody', 'fearing', 'grandkids', 'laughing', 'playing', 'garden', 'got', 'tea', 'delivered', 'feeling', 'bit', 'better', 'covid', 'tea', 'recovery'] 260526
# ['new', 'investments', 'community', 'based', 'care', 'reduce', 'stress', 'cdnhealth', 'network', 'improve', 'access', 'care', 'eg', 'allowing', 'funding', 'pharmacists', 'provide', 'point', 'care', 'testing', 'prescribe', 'covid', 'treatments', 'paxlovid', 'uptake', 'treatments', 'burden', 'hospitals'] 260527
# ['alvinllum', 'rest', 'world', 'moving', 'living', 'covid', 'china', 'hongkong', 'take', 'tougher', 'tougher', 'measures', 'public', 'health', 'surveillance'] 260528
# ['yes', 'waiting', 'educational', 'video', 'since', 'beginning', 'pandemic', 'helpful', 'aid', 'people', 'see', 'happening', 'invisible', 'enemy', 'needs', 'visible', 'covid'] 260529
# ['day', 'covid', 'deaths', 'county', 'wv', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260530
# ['hello', 'nominate', 'end', 'quote', 'repeat', 'line', 'hello', 'nominate', 'best', 'author', 'see', 'related', 'pikture', 'heatwave', 'covid', 'wizkid', 'whiz', 'khalifer', 'smokes', 'big', 'reefers'] 260531
# ['everydosecounts', 'haltonon', 'accepting', 'walk', 'ins', 'ages', 'covid', 'doses', 'paediatric', 'community', 'clinics', 'date', 'clinic', 'times', 'locations', 'visit'] 260532
# ['check', 'gig', 'fiverr', 'design', 'creative', 'pdf', 'lead', 'magnet', 'ebook', 'annual', 'report', 'austriangp', 'biblebuild', 'bbau', 'clifton', 'covid', 'chemtrails', 'daterush', 'daterushreunion', 'gangland', 'genshinlmpact', 'heatwave', 'loveisland', 'nhlanhla_lux', 'populationcontrollaw'] 260533
# ['day', 'covid', 'deaths', 'county', 'wv', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260534
# ['seeking', 'twins', 'covid', 'study'] 260535
# ['study', 'finds', 'practice', 'intermittent', 'fasting', 'experience', 'less', 'severe', 'covid', 'complications', 'learn', 'bmjnutrition', 'globalhealth', 'healthcare', 'meded', 'emednews'] 260536
# ['people', 'learning', 'disabilities', 'resuscitate', 'notices', 'scribbled', 'medical', 'notes', 'covid', 'lockdown', 'vile', 'unethical', 'big', 'jump', 'deny', 'intensive', 'care'] 260537
# ['world', 'full', 'opportunities', 'attached', 'opportunities', 'new', 'beginnings', 'returns', 'opportunities', 'endless', 'creating', 'better', 'priceless', 'keepupthefightapparel', 'austriangp', 'genshinlmpact', 'bb', 'covid', 'daterushreunion', 'mondayvibes'] 260538
# ['go', 'gentle', 'rousing', 'hate', 'age', 'burn', 'news', 'today', 'rage', 'rage', 'lying', 'state', 'leadershipcontest', 'brexit', 'herdimmunity', 'redwall', 'covid', 'bbcbias', 'squirrel', 'contraception', 'poetry', 'brian_bilston'] 260539
# ['mumbai', 'monday', 'reported', 'covid', 'cases', 'lowest', 'single', 'day', 'rise', 'may', 'death', 'toll', 'remained', 'unchanged', 'metropolis', 'third', 'consecutive', 'day'] 260540
# ['ampincivero', 'lcwf_tbk', 'drnisreenalwan', 'toxoplasmosis', 'gondii', 'shown', 'alter', 'behavior', 'infected', 'rodents', 'ways', 'increase', 'rodents', 'chances', 'preyed', 'upon', 'maybe', 'covid', 'affects', 'brain', 'similar', 'ways', 'disinhibition', 'host', 'aid', 'spread'] 260541
# ['day', 'covid', 'deaths', 'county', 'wa', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260542
# ['new', 'coronavirus', 'mutant', 'raises', 'concerns', 'india', 'beyond'] 260543
# ['efficacy', 'polyherbal', 'formulations', 'prevention', 'covid', 'infection', 'high', 'risk', 'subjects', 'randomized', 'open', 'label', 'controlled', 'clinical', 'trial', 'covid', 'herbalplants', 'medicinalplants', 'pandemia', 'tratamentoprecoce'] 260544
# ['attention', 'indigenous', 'organizations', 'heritage', 'collection', 'check', 'cdnheritage', 'new', 'covid', 'recovery', 'fund', 'museums', 'assistance', 'program', 'apply', 'august', 'info', 'economicrecovery'] 260545
# ['hoping', 'dodged', 'covid', 'bullet', 'today', 'gums', 'gouged', 'hygienist', 'big', 'gap', 'man', 'see', 'least', 'hepa', 'filters', 'rooms', 'waiting', 'room', 'except', 'unmasked', 'receptionist'] 260546
# ['need', 'relationalapproaches', 'traumainformedapproaches', 'connection', 'supported', 'views', 'shared', 'children', 'youngpeople', 'understanding', 'impact', 'covid', 'poverty', 'systemic', 'factors', 'informed', 'pupilviews', 'livedexperience'] 260547
# ['day', 'covid', 'deaths', 'county', 'wa', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260548
# ['play', 'stupid', 'games', 'win', 'stupid', 'prizes', 'guess', 'fun', 'time', 'florida', 'knew', 'risk', 'see', 'goes', 'spose', 'far', 'blows', 'covid'] 260549
# ['well', 'start', 'selling', 'nfts', 'getting', 'solana', 'personal', 'opinion', 'crisis', 'beginning', 'world', 'war', 'ukraine', 'inflation', 'united', 'states', 'due', 'coronavirus', 'fear', 'increase', 'federal', 'reserve', 'system', 'etc'] 260550
# ['check', 'gig', 'fiverr', 'nft', 'banner', 'discord', 'banner', 'youtube', 'banner', 'banner', 'design', 'austriangp', 'biblebuild', 'bbau', 'chemtrails', 'clifton', 'covid', 'daterush', 'daterushreunion', 'gangland', 'genshinlmpact', 'heatwave', 'loveisland', 'nadinelustredeleterstorycon'] 260551
# ['day', 'covid', 'deaths', 'county', 'va', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260552
# ['large', 'movement', 'within', 'fascist', 'community', 'associate', 'organ', 'damage', 'multiple', 'exposures', 'covid', 'long', 'covid', 'vaccine', 'injury', 'mess', 'yes', 'seems', 'people', 'getting', 'sicker', 'country', 'without', 'public', 'health', 'care', 'regime'] 260553
# ['love', 'nature', 'mobile', 'landscape', 'shoot', 'bike', 'loveisland', 'photography', 'covid', 'vawulence', 'deborah', 'art'] 260554
# ['australia', 'media', 'reporting', 'th', 'shot', 'end', 'year', 'confirmed', 'news', 'covid', 'vaccinebusiness'] 260555
# ['day', 'covid', 'deaths', 'county', 'va', 'latest', 'covid', 'insights', 'analytics', 'team', 'using', 'usafacts', 'datavisualization', 'datascience', 'analytics', 'healthtech', 'data', 'covid', 'publichealth', 'covid', 'globalhealth'] 260556
# ['need', 'fact', 'checks', 'families', 'put', 'offices', 'covid'] 260557

# %%
#Check
#cursor = sql_db.cursor()
b=0
offset = 0#counter for offset
TEST = [0] #starting with a non-empty results to make sure we get into loop in the first place

while TEST:
    cursor.execute("select * from twitter where text_preproc IS NOT NULL limit 100 offset {0};".format(offset))
    offset += 100
    TEST = cursor.fetchall()
    if not TEST:  # Check if there are no more results
        break
    b+=1
    if b == 10:
        break

# %%
TEST[1]
