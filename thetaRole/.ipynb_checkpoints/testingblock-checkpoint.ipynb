# %%
#prepare the docs, doc_reln, vocab, and vocab_reln
wordtest = ["london",
                "england",
                "reuters",
                "harry",
                "turns",
                "insists",
                "gains",
                "potter",
                "star",
                "daniel",
                "radcliffe",
                "access",
                "fortune",
                "reported",
                "million",
                "million",
                "monday",
                "cast",
                "money",
                "spell",
                "daniel",
                "radcliffe",
                "actor",
                "potter",
                "harry",
                "potter",
                "harry",
                "order",
                "phoenix",
                "disappointment",
                "columnists",
                "gossip",
                "around",
                "world",
                "young",
                "plans",
                "fritter",
                "cash",
                "away",
                "cars",
                "fast",
                "drink",
                "parties",
                "celebrity",
                "told",
                "plan",
                "interviewer",
                "month",
                "people",
                "buy",
                "soon",
                "suddenly",
                "collection",
                "turn",
                "massive",
                "sports",
                "car",
                "similar",
                "australian",
                "earlier",
                "extravagant",
                "particularly",
                "things",
                "things",
                "buying",
                "cost",
                "pounds",
                "books",
                "cds",
                "dvds",
                "able",
                "radcliffe",
                "gamble",
                "currently",
                "places",
                "movie",
                "buy",
                "see",
                "casino",
                "drink",
                "pub",
                "film",
                "horror",
                "hostel",
                "part",
                "number",
                "chart",
                "box",
                "office",
                "details",
                "mark",
                "birthday",
                "landmark",
                "wraps",
                "agent",
                "publicist",
                "comment",
                "plans",
                "definitely",
                "sort",
                "party",
                "interview",
                "reading",
                "hopefully",
                "none",
                "radcliffe",
                "earnings",
                "held",
                "films",
                "first",
                "potter",
                "fund",
                "trust",
                "able",
                "touch",
                "growing",
                "despite",
                "actor",
                "keeping",
                "fame",
                "riches",
                "feet",
                "firmly",
                "ground",
                "told",
                "looking",
                "reporters",
                "month",
                "people",
                "always",
                "goes",
                "star",
                "rails",
                "last",
                "try",
                "hard",
                "way",
                "easy",
                "outing",
                "latest",
                "breaking",
                "records",
                "reprise",
                "wizard",
                "boy",
                "potter",
                "harry",
                "order",
                "phoenix",
                "sides",
                "atlantic",
                "role",
                "films",
                "last",
                "watch",
                "give",
                "review",
                "potter",
                "latest",
                "life",
                "however",
                "beyond",
                "potter",
                "londoner",
                "filmed",
                "movie",
                "called",
                "jack",
                "boy",
                "kipling",
                "author",
                "rudyard",
                "son",
                "due",
                "year",
                "release",
                "later",
                "appear",
                "film",
                "boys",
                "december",
                "australian",
                "boys",
                "escape",
                "orphanage",
                "earlier",
                "year",
                "debut",
                "playing",
                "stage",
                "teenager",
                "tortured",
                "shaffer",
                "peter",
                "equus",
                "meanwhile",
                "braced",
                "adult",
                "told",
                "reuters",
                "scrutiny",
                "closer",
                "even",
                "media",
                "legally",
                "going",
                "sort",
                "game",
                "fair",
                "friend",
                "copyright",
                "reuters",
                "rights",
                "published",
                "material",
                "may",
                "broadcast",
                "rewritten",
                "redistributed"
            ]
relntest =[
                [
                    "nn.dep"
                ],
                [
                    "nn.gov",
                    "dep.gov",
                    "dep.gov",
                    "advcl.gov",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "dep.dep"
                ],
                [
                    "dep.dep",
                    "dobj.gov"
                ],
                [
                    "advcl.dep",
                    "mark.gov",
                    "nsubj.gov",
                    "dep.gov",
                    "prep.gov"
                ],
                [
                    "conj.dep",
                    "nsubj.gov",
                    "ccomp.gov"
                ],
                [
                    "dobj.dep",
                    "amod.gov",
                    "nn.gov",
                    "nn.gov",
                    "nn.gov",
                    "dep.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "dep.dep",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "amod.gov",
                    "amod.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "amod.dep",
                    "number.gov",
                    "dep.gov"
                ],
                [
                    "number.dep"
                ],
                [
                    "pobj.dep"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "aux.gov",
                    "neg.gov",
                    "dobj.gov",
                    "prep.gov"
                ],
                [
                    "det.gov",
                    "nsubj.dep"
                ],
                [
                    "dobj.dep",
                    "det.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.gov",
                    "prep.gov",
                    "appos.gov",
                    "nsubj.dep"
                ],
                [
                    "appos.dep",
                    "det.gov",
                    "amod.gov"
                ],
                [
                    "pobj.dep",
                    "nn.gov",
                    "prep.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "pobj.dep",
                    "amod.gov",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "conj.dep",
                    "det.gov",
                    "prep.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "nn.gov",
                    "prep.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "prep.dep",
                    "pobj.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "infmod.gov"
                ],
                [
                    "infmod.dep",
                    "aux.gov",
                    "dobj.gov",
                    "advmod.gov",
                    "prep.gov"
                ],
                [
                    "dobj.dep",
                    "poss.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "pobj.dep",
                    "amod.gov",
                    "conj.gov",
                    "conj.gov",
                    "cc.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "conj.dep"
                ],
                [
                    "conj.dep",
                    "nn.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "ccomp.gov",
                    "nsubj.gov",
                    "dobj.gov",
                    "tmod.gov"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "aux.gov",
                    "neg.gov",
                    "xcomp.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "amod.gov"
                ],
                [
                    "tmod.dep",
                    "advmod.gov",
                    "det.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "rcmod.gov"
                ],
                [
                    "rcmod.dep",
                    "nsubj.gov",
                    "advmod.gov",
                    "advmod.gov",
                    "ccomp.gov"
                ],
                [
                    "advmod.dep",
                    "advmod.gov",
                    "dep.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "det.gov",
                    "amod.gov",
                    "nn.gov",
                    "nn.gov",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "dep.dep",
                    "mark.gov",
                    "nsubj.gov",
                    "dobj.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "amod.dep"
                ],
                [
                    "amod.dep"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "ccomp.dep",
                    "aux.gov",
                    "cop.gov",
                    "advmod.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "nsubj.gov",
                    "cop.gov",
                    "prep.gov"
                ],
                [
                    "det.gov",
                    "nsubj.dep"
                ],
                [
                    "pcomp.dep"
                ],
                [
                    "poss.dep",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "num.gov",
                    "dep.gov"
                ],
                [
                    "dep.dep",
                    "cc.gov",
                    "cc.gov",
                    "conj.gov",
                    "conj.gov"
                ],
                [
                    "conj.dep"
                ],
                [
                    "conj.dep"
                ],
                [
                    "prep.gov",
                    "nsubj.gov",
                    "aux.gov",
                    "cop.gov",
                    "xcomp.gov",
                    "advcl.dep"
                ],
                [
                    "nsubj.dep"
                ],
                [
                    "xcomp.dep",
                    "aux.gov",
                    "prep.gov",
                    "conj.gov",
                    "conj.gov",
                    "cc.gov"
                ],
                [
                    "dep.dep"
                ],
                [
                    "dep.dep",
                    "num.gov"
                ],
                [
                    "pobj.dep",
                    "poss.gov",
                    "nn.gov",
                    "num.gov",
                    "prep.gov"
                ],
                [
                    "conj.dep",
                    "dobj.gov",
                    "prep.gov"
                ],
                [
                    "conj.dep",
                    "dobj.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "nn.gov",
                    "dep.gov",
                    "dep.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "dep.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "amod.gov",
                    "nn.gov",
                    "nn.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "prep.gov",
                    "nsubj.dep"
                ],
                [
                    "pcomp.dep",
                    "advmod.gov",
                    "nsubj.gov",
                    "aux.gov",
                    "dobj.gov"
                ],
                [
                    "dobj.dep",
                    "poss.gov",
                    "nn.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "pobj.dep"
                ],
                [
                    "poss.gov",
                    "cc.gov",
                    "conj.gov",
                    "nsubj.dep"
                ],
                [
                    "conj.dep"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "poss.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "null.dep",
                    "advmod.gov",
                    "nsubj.gov",
                    "aux.gov",
                    "aux.gov",
                    "prep.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "nsubj.dep",
                    "prep.gov"
                ],
                [
                    "possessive.gov",
                    "poss.dep"
                ],
                [
                    "poss.gov",
                    "prep.gov",
                    "nsubjpass.dep"
                ],
                [
                    "nsubjpass.gov",
                    "aux.gov",
                    "auxpass.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "amod.gov",
                    "num.gov",
                    "nn.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "nn.gov",
                    "rcmod.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "rcmod.dep",
                    "dobj.gov",
                    "nsubj.gov",
                    "aux.gov",
                    "neg.gov",
                    "cop.gov",
                    "xcomp.gov"
                ],
                [
                    "xcomp.dep",
                    "aux.gov"
                ],
                [
                    "pcomp.dep",
                    "nsubj.gov",
                    "dobj.gov"
                ],
                [
                    "pcomp.gov",
                    "prep.dep"
                ],
                [
                    "nsubj.dep",
                    "det.gov"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "aux.gov",
                    "dobj.gov",
                    "advmod.gov",
                    "prep.gov"
                ],
                [
                    "dobj.dep",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "conj.dep"
                ],
                [
                    "dobj.dep",
                    "poss.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "ccomp.gov",
                    "nsubj.gov",
                    "dobj.gov",
                    "tmod.gov"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "aux.gov",
                    "advmod.gov",
                    "xcomp.gov"
                ],
                [
                    "dobj.dep"
                ],
                [
                    "tmod.dep",
                    "amod.gov"
                ],
                [
                    "nsubj.dep"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "prep.gov"
                ],
                [
                    "num.gov",
                    "nsubj.dep"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "cc.gov",
                    "dep.gov",
                    "advmod.gov",
                    "xcomp.gov"
                ],
                [
                    "advmod.dep",
                    "advmod.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov"
                ],
                [
                    "advcl.dep",
                    "mark.gov",
                    "nsubj.gov",
                    "aux.gov",
                    "cop.gov",
                    "advmod.gov",
                    "prep.gov"
                ],
                [
                    "poss.gov",
                    "amod.gov",
                    "prep.gov",
                    "nsubj.dep"
                ],
                [
                    "amod.dep"
                ],
                [
                    "nsubj.gov",
                    "aux.gov",
                    "dobj.gov",
                    "prep.gov",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "dobj.dep"
                ],
                [
                    "conj.dep",
                    "nsubj.gov",
                    "aux.gov",
                    "dobj.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "nn.gov",
                    "prep.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "pobj.dep",
                    "amod.gov",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "conj.dep",
                    "det.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "det.gov",
                    "amod.gov",
                    "num.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "dobj.gov",
                    "dep.gov"
                ],
                [
                    "dep.dep",
                    "dobj.gov"
                ],
                [
                    "dobj.dep",
                    "poss.gov",
                    "prep.gov"
                ],
                [
                    "possessive.gov",
                    "poss.dep"
                ],
                [
                    "amod.dep"
                ],
                [
                    "nsubj.dep",
                    "prep.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "prep.dep",
                    "pobj.gov"
                ],
                [
                    "pobj.dep"
                ],
                [
                    "det.gov",
                    "nsubj.dep"
                ],
                [
                    "nsubj.gov",
                    "aux.gov",
                    "dobj.gov",
                    "prep.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "nn.gov",
                    "partmod.gov"
                ],
                [
                    "partmod.dep",
                    "dep.gov"
                ],
                [
                    "dep.dep",
                    "poss.gov",
                    "nn.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "pobj.dep",
                    "nn.gov",
                    "nn.gov",
                    "cc.gov",
                    "conj.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.dep"
                ],
                [
                    "conj.dep",
                    "poss.gov",
                    "amod.gov",
                    "dep.gov"
                ],
                [
                    "amod.dep",
                    "prep.gov"
                ],
                [
                    "dep.dep",
                    "advmod.gov",
                    "det.gov"
                ],
                [
                    "pobj.dep"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "nsubj.gov",
                    "aux.gov",
                    "advmod.gov",
                    "prep.gov",
                    "parataxis.gov"
                ],
                [
                    "parataxis.dep",
                    "det.gov",
                    "amod.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "amod.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "amod.dep"
                ],
                [
                    "pobj.dep",
                    "num.gov",
                    "rcmod.gov"
                ],
                [
                    "rcmod.dep",
                    "nsubj.gov",
                    "dobj.gov"
                ],
                [
                    "dobj.dep",
                    "det.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "advmod.gov",
                    "det.gov",
                    "tmod.dep"
                ],
                [
                    "dobj.dep",
                    "poss.gov",
                    "nn.gov"
                ],
                [
                    "xcomp.dep",
                    "dobj.gov",
                    "prep.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "dobj.dep",
                    "det.gov",
                    "amod.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "pobj.dep",
                    "nn.gov",
                    "possessive.gov",
                    "dep.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "dep.dep"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "advmod.gov",
                    "nsubjpass.gov",
                    "auxpass.gov",
                    "prep.gov",
                    "ccomp.gov",
                    "dep.gov",
                    "ccomp.dep"
                ],
                [
                    "ccomp.dep",
                    "advmod.gov",
                    "advmod.gov",
                    "dep.gov",
                    "nsubj.gov",
                    "cop.gov",
                    "det.gov"
                ],
                [
                    "ccomp.gov",
                    "nsubj.gov",
                    "dobj.gov"
                ],
                [
                    "dobj.dep"
                ],
                [
                    "pobj.dep",
                    "num.gov"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "advmod.gov",
                    "advmod.dep"
                ],
                [
                    "advmod.gov",
                    "num.dep"
                ],
                [
                    "advmod.dep"
                ],
                [
                    "ccomp.dep",
                    "nsubj.gov",
                    "aux.gov",
                    "xcomp.gov"
                ],
                [
                    "xcomp.dep",
                    "aux.gov",
                    "cop.gov",
                    "amod.gov",
                    "prep.gov"
                ],
                [
                    "pobj.dep",
                    "amod.gov"
                ],
                [
                    "amod.dep"
                ],
                [
                    "pobj.dep",
                    "det.gov"
                ],
                [
                    "nn.dep"
                ],
                [
                    "nn.gov",
                    "num.gov"
                ],
                [
                    "det.gov",
                    "nsubj.dep"
                ],
                [
                    "ccomp.dep",
                    "nsubjpass.gov",
                    "aux.gov",
                    "neg.gov",
                    "auxpass.gov",
                    "conj.gov",
                    "conj.gov",
                    "conj.gov",
                    "cc.gov"
                ],
                [
                    "nsubjpass.dep"
                ],
                [
                    "aux.dep"
                ],
                [
                    "conj.dep"
                ],
                [
                    "conj.dep"
                ],
                [
                    "conj.dep"
                ]
            ]
len(wordtest)
len(relntest)

# %%
def fit(self):
        '''
        Run gibbs sampling for n iterations to assign theta role and topic to each word
        '''
        for i in tqdm(range(self.n_iters)):
            for d, doc in enumerate(self.corpus_hat):
                N = len(doc)

                for word in doc:
                    z, y, idx, relns = word.z, word.y, word.idx, word.relns
                
                    # subtract count for current topic and theta role; 
                    self.n_d_k[d, z] -= 1
                    self.n_k_w[z, idx] -= 1
                    self.n_t_w[y, idx] -=1
                    self.n_k[z] -= 1
                    for reln in relns:
                        self.n_t_reln[y, self.reln2id[reln]] -= 1
                    self.n_d_t[d, y] -= 1
                    self.n_t_k[y, z] -= 1
                    self.n_t[y] -= 1

                    # calculate conditional probability distribution for topic selection
                    # p(k|w,d) =~ p(w | k)* p(k | d) 
                    p_k = np.zeros(self.K)
                    for k in range(self.K):
                        p_w_k = (self.n_k_w[k, idx] + self.eta) / (self.n_k[k] + self.eta * self.V)#left side of the formula
                        p_k_d = (self.n_d_k[d, k] + self.alpha) / (N + self.K * self.alpha) #right side of the formula in the LDA..  N:Total number of tokens (words) in document i (i.e., the lentgh of the document:)
                        p_k[k] = p_k_d * p_w_k  

                    # select topic
                    z = np.random.choice(self.K, p=p_k / sum(p_k))
                    word.z = z
                    
                    # correct up to this point!!
                    # update counts for the selected topic
                    self.n_d_k[d, z] += 1
                    self.n_k_w[z, idx] += 1
                    self.n_t_w[y, idx] +=1
                    self.n_k[z] += 1

                    # probability of current that role,  given current grammatical relations, and for the selected topic z? 
                    # p(tr | reln, w, z, d) ~ p(w | tr) * p(reln | tr) * p(z | tr) *p(tr|d)
                    p_t_reln = np.zeros((self.T, self.R))
                    p_t_reln_w_z_d = np.zeros(self.T)
                    
                    for reln in relns:
                        for t in range(self.T):
                            #p(t|d)
                            p_t_d = (self.n_d_t[d, t] + self.gamma) / (N + self.T * self.gamma) #N is total number of theta role in document di, which is equal to the the length of document as each word is assigned a theta role to.
                            #p(reln|t)
                            p_reln_t = (self.n_t_reln[t, self.reln2id[reln]] + self.lam)/ (np.sum(self.n_t_reln[t, :] + self.lam * self.R)) # is n_t[t] = sum of all relns that are assigned to this theta role t
                            #p(z|d)? why do we need it here? we should not perhaps.?????????????????????????????????????????????
                            p_z_d = (self.n_d_k[d, z] + self.alpha) / (N + self.K * self.alpha)
                            #p(z|t)
                            #p_z_t = (self.n_t_k[t, z] + self.gamma) \
                            #     / (self.n_t[t] + self.gamma * self.T) # we defined a prior for topic distribution over theta role, named in omega
                            #p(z|t)
                            p_z_t = (self.n_t_k[t, z] + self.omega) \
                                 / (np.sum(self.n_t_k[t, :]) + self.omega * self.T) # we defined a prior for topic distribution over theta role, named in omega 
                            #Note: totlal number of topics for theta role t = np.sum(self.n_t_k[t, :])
                        #need the formula for p_z_d_t. what does it present? p(z,t|d) = p(z|d)p(z|t) or is it p(z|d, t)= p(z|d)p(z|t), i think it is the latter
                            
                            p_w_t = (self.n_t_w[t, idx] + self.etaprime) / (np.sum(self.n_t_w[t, :]) + self.etaprime * self.V)#
                            #now we have every part of p(t|reln, w, z, d)
                            p_t_reln_w_z_d[t] = p_w_t * p_z_t * p_reln_t * p_t_d #what is the dimention of this one? 
                            
                            #THE REST OF IT IS BASED ON CHACE'S CODE AND NOT SURE HOW TO ADOPT IT FOR MY APPRAOCH...
                            p_z_d_t = p_z_d * p_z_t
                            #p(t|reln) = ?
                            p_t_reln[t, self.reln2id[reln]] = p_t_d * p_reln_t * p_z_d_t
                            #[t,z] vs. [z, t]
                    
                    # maybe we should also care about and select theta role for each relation using probability distribution?
                    
                    # HOW TO CHANGE IT TO BE BASED ON "p_t_reln_w_z_d" that I created now? 
                    p_t = np.sum(p_t_reln, axis=1)
                    y = np.random.choice(self.T, p=p_t / np.sum(p_t))
                    word.y = y
                    
                    #new modifications; will it work?
                    y = np.random.choice(self.T, p=p_t_reln_w_z_d / np.sum(p_t_reln_w_z_d))
                    word.y = y
                    
                    #z.y : follow the same strategy above to assign theta role for each topic... afterwards.. here is not working because we want to calcualte the matrix .... 
    
                    # update counts for selected theta role
                    for reln in relns:
                        self.n_t_reln[y, self.reln2id[reln]] += 1
                    self.n_d_t[d, y] += 1
                    self.n_t_k[y, z] += 1
                    self.n_t[y] += 1 #number of words assigned to this theta role y 
                    
                    #prob of all the theta role for each topic..
                    #prob of theta role for a word
                    
                    # p(t|w) = ???
                    #p(t|z) = (done below)
    
    
    
    
    #z.y: follow the same strategy above to assign theta role for each topic... afterwards..
    
    #after gips sampling              
    # p(reln|w) = p(reln|y)p(y|z)p(z|w)
# Out:
#   File "/share/ceph/scratch/zha219/10019626/ipykernel_388757/1028445023.py", line 54
#     p_z_d = (self.n_d_k[d, z] + self.alpha) / (N + self.K * self.alpha)
#     ^
# SyntaxError: invalid syntax
